# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoV79080679/DSCI/blob/main/ProyectoDS_parteI_Valderrama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Estudio de factores determinantes en casos de depresión

# %% [markdown]
# El dataset selecionado muestra  estudiantes con depresión o no,  observandose variables que identifican a cada sujeto junto a factores externos asociados al estado depresivo. Lo que se busca en este estudio es establecer la relacion de estos factores con la depresión y la posible influencia en el diagnóstico.

# %% [markdown]
# Las interrogantes plateandas son las siguientes:
# *   ¿Puede es el género estas asociado a la depresión?List item

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url="https://raw.githubusercontent.com/LeoV79080679/DSCI/refs/heads/main/student_depression_dataset.csv"
df=pd.read_csv(url, index_col=0)

df
# Out:
#         Gender   Age           City Profession  Academic Pressure  \
# id
# 2         Male  33.0  Visakhapatnam    Student                5.0
# 8       Female  24.0      Bangalore    Student                2.0
# 26        Male  31.0       Srinagar    Student                3.0
# 30      Female  28.0       Varanasi    Student                3.0
# 32      Female  25.0         Jaipur    Student                4.0
# ...        ...   ...            ...        ...                ...
# 140685  Female  27.0          Surat    Student                5.0
# 140686    Male  27.0       Ludhiana    Student                2.0
# 140689    Male  31.0      Faridabad    Student                3.0
# 140690  Female  18.0       Ludhiana    Student                5.0
# 140699    Male  27.0          Patna    Student                4.0
#
#         Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# id
# 2                 0.0  8.97                 2.0               0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27901 entries, 2 to 140699
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Gender                                 27901 non-null  object
#  1   Age                                    27901 non-null  float64
#  2   City                                   27901 non-null  object
#  3   Profession                             27901 non-null  object
#  4   Academic Pressure                      27901 non-null  float64
#  5   Work Pressure                          27901 non-null  float64
#  6   CGPA                                   27901 non-null  float64
#  7   Study Satisfaction                     27901 non-null  float64
#  8   Job Satisfaction                       27901 non-null  float64
#  9   Sleep Duration                         27901 non-null  object
# ...

# %%
df.describe()
# Out:
#                 Age  Academic Pressure  Work Pressure          CGPA  \
# count  27901.000000       27901.000000   27901.000000  27901.000000
# mean      25.822300           3.141214       0.000430      7.656104
# std        4.905687           1.381465       0.043992      1.470707
# min       18.000000           0.000000       0.000000      0.000000
# 25%       21.000000           2.000000       0.000000      6.290000
# 50%       25.000000           3.000000       0.000000      7.770000
# 75%       30.000000           4.000000       0.000000      8.920000
# max       59.000000           5.000000       5.000000     10.000000
#
#        Study Satisfaction  Job Satisfaction  Work/Study Hours    Depression
# count        27901.000000      27901.000000      27901.000000  27901.000000
# mean             2.943837          0.000681          7.156984      0.585499
# std              1.361148          0.044394          3.707642      0.492645
# ...
